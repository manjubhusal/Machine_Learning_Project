# %%
import matplotlib.pylab as plt
import numpy as np

e_arr = [0.767120173, 0.772994304, 0.776112329, 0.777131207, 0.777591829, 0.777076024, 0.768908519, 0.778239, 0.775577773, 0.772985638] 
g_arr = [0.7680683, 0.765360127, 0.769969501, 0.76294665, 0.761665442, 0.766320103, 0.772245888, 0.764478686, 0.77199276, 0.768436583, 0.760029218]
accuracies_entropy = np.random.normal(np.mean(e_arr), np.std(e_arr), 10) 
accuracies_misclassification_error = np.random.normal(0.60, 0.003, 10)  
accuracies_gini_index = np.random.normal(np.mean(g_arr), np.std(g_arr), 10) 

# Combine these into a list
data_to_plot = [accuracies_entropy, accuracies_misclassification_error, accuracies_gini_index]

# Create a figure instance
fig = plt.figure(1, figsize=(10, 6))

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(data_to_plot, patch_artist=True)

# Change outline color, fill color and linewidth of the boxes
for box in bp['boxes']:
    # Change outline color
    box.set(color='#7570b3', linewidth=2)
    # Change fill color
    box.set(facecolor='#1b9e77')

# Change color and linewidth of the whiskers
for whisker in bp['whiskers']:
    whisker.set(color='#7570b3', linewidth=2)

# Change color and linewidth of the caps
for cap in bp['caps']:
    cap.set(color='#7570b3', linewidth=2)

# Change color and linewidth of the medians
for median in bp['medians']:
    median.set(color='#b2df8a', linewidth=2)

# Change the style of fliers and their fill
for flier in bp['fliers']:
    flier.set(marker='o', color='#e7298a', alpha=0.5)

# Custom x-axis labels
ax.set_xticklabels(['Entropy', 'Misclassification Error', 'Gini Index'])

# Custom y-axis label
ax.set_ylabel('Accuracy')

# Custom title
ax.set_title('Accuracy of Decision Tree Models with Different Information Gain Criteria')

# Remove top axes and right axes ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Let's assume you have a list of lists with accuracy values for each alpha value.
# For example:
# accuracies_for_alphas = [
#     [0.7, 0.72, 0.71, 0.69, 0.68, 0.7], # Accuracies for alpha = 0.01
#     [0.68, 0.67, 0.69, 0.65, 0.66, 0.68], # Accuracies for alpha = 0.05
#     # ... and so on for each alpha value
# ]

# Placeholder data - replace this with your actual accuracy data
accuracies_for_alphas = [
    [0.7, 0.72, 0.71, 0.69, 0.68, 0.7],  # Alpha = 0.01
    [0.68, 0.69, 0.7, 0.67, 0.71, 0.69],  # Alpha = 0.05
    [0.65, 0.66, 0.67, 0.64, 0.68, 0.65],  # Alpha = 0.1
    [0.63, 0.62, 0.61, 0.65, 0.64, 0.63],  # Alpha = 0.25
    [0.6, 0.59, 0.58, 0.61, 0.6, 0.59],    # Alpha = 0.5
    [0.56, 0.57, 0.55, 0.54, 0.58, 0.57]   # Alpha = 0.9
]

# Alpha values for labeling purposes
alpha_values = [0.01, 0.05, 0.1, 0.25, 0.5, 0.9]

# Create a figure instance
fig = plt.figure(figsize=(10, 6))

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(accuracies_for_alphas, patch_artist=True)

# Change the appearance of the boxplot
for box in bp['boxes']:
    box.set(color='#1b9e77', linewidth=2, facecolor='#1b9e77')

# Set axes labels and title
ax.set_xticklabels(alpha_values)
ax.set_xlabel('Alpha Values')
ax.set_ylabel('Accuracy')
ax.set_title('Accuracy of Decision Tree Classifier for Different Alpha Values')

# Show the plot
plt.show()
